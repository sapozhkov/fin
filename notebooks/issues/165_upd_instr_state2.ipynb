# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from app import AppConfig

AppConfig.INSTRUMENT_ON_THRESHOLD
# Out:
# 0.1

# %%
from app.tasks import UpdInstrumentTask
from app.models import Task
from app import create_app

app = create_app()
with app.app_context():
    task = Task(
        data = '4'
    )

    UpdInstrumentTask.run(task)
# Out:
# Инструмент: <Instrument 4 'RNFT+ 2/fan3:0/2 x l1 x 0.4(+x0.1)¤ ' [2139186563] On>
# Расчет на дату 2024-11-16, глубина дней: 3
# Исходный: RNFT+ 2/fan3:0/2 x l1 x 0.4(+x0.1)¤
# Новый:    RNFT+ 2/fan3:0/2 x l1 x 0.4(+x0.1)¤ , profit 1.0
# Порог прибыли 0.1, расчетная прибыль 1.0
# Активность не меняем
