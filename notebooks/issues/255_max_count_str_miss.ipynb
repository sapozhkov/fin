# %% [markdown]
# ## Проверить эффективное использование баланса #255

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from app.config import RunConfig

config = RunConfig.from_repr_string('MVID+ 4/fan4:0/2 x l13 x 0.6¤ |u0.01 d0.0|')

config
# Out:
# MVID+ 4/fan4:0/2 x l13 x 0.6¤ |u0.01 d0.0|

# %%
config.to_string()
# Out:
# 'ticker=MVID,step_size=0.6,step_set_orders_cnt=2,step_lots=13,pretest_type=fan,pretest_period=4,majority_trade=True,stop_up_p=0.01'
