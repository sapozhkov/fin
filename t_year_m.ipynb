# %% [markdown]
# ## Тестирование стратегии на промежутке дней (год)
# - запуск тестового алгоритма на любом временном промежутке
# - возможность запуска разных комбинаций настроек и сравнения результатов

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from dotenv import load_dotenv

load_dotenv()

TOKEN = os.getenv("INVEST_TOKEN")

TICKER = 'RNFT'
FIGI = 'BBG00F9XX7H4'

# %%
from lib.task_progress import TaskProgress
from test_env.test_alg import TestAlgorithm
from concurrent.futures import ThreadPoolExecutor, as_completed

# Определение максимального количества потоков
max_workers = 4  # N

# Создание списка всех параметров для тестов
# test_params = [
#     (max_shares, threshold_b_n, threshold_s_n, step_size, step_cnt, sleep_t)
#     # for max_shares in [5]
#     for max_shares in [1, 2, 3, 5, 8, 13]
#     for threshold_b_n in [3, 5, 8]
#     for threshold_s_n in [3, 5, 8]
#     for step_size in [.5, .7, 1]
#     for step_cnt in [3, 4]
#     for sleep_t in [1*60]
# ]

test_params = [
    (max_shares, threshold_b_n, threshold_s_n, step_size, step_cnt, sleep_t)
    for max_shares in [3]
    for threshold_b_n in [3]
    for threshold_s_n in [0]
    for step_size in [1]
    for step_cnt in [3]
    for sleep_t in [1*60]
]
        
def run_test(max_shares, threshold_b_n, threshold_s_n, step_size, step_cnt, sleep_t):
    test_alg_ = TestAlgorithm(TOKEN, TICKER, FIGI, False)
    result = test_alg_.test(
        last_test_date='2024-03-15',
        test_days_num=251,  # 251,
        
        start_time='07:00',  # 10:00
        end_time='15:29',  # 18:29
        
        max_shares=max_shares,
        # base_shares=3,
        threshold_buy_steps=threshold_b_n,
        threshold_sell_steps=threshold_s_n,
        step_size=step_size,
        step_cnt=step_cnt,

        # quit_on_balance_up_percent=2,
        # quit_on_balance_down_percent=1,

        sleep_trading=sleep_t,
    )
    return result

results = []
progress = TaskProgress(len(test_params))

# Использование ThreadPoolExecutor для выполнения тестов в многопоточном режиме
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    # Запуск задач
    future_to_params = {executor.submit(run_test, *params): params for params in test_params}
    
    # Получение результатов выполнения задач по мере их завершения
    for future in as_completed(future_to_params):
        params = future_to_params[future]
        try:
            res = future.result()
            results.append(res)
            progress.update_progress()
        except Exception as exc:
            print(f'Generated an exception: {exc} for params: {params}')

# Вывод результатов или их дальнейшая обработка
sorted_results = sorted(results, key=lambda x: x['profit_p'], reverse=True)

print()
for item in sorted_results:
    print(item)

# sorted_results
# Out:
# Запуск в 01:53
# Закончено в 01:53, длительность 0:00:14
#
# {'balance': 89.2, 'profit_p': '0.17', 'balance_change_avg': -0.34, 'days': 251, 'success_days': 106, 'success_p': 0.42, 'sleep_trading': 60, 'max_shares': 3, 'threshold_buy_steps': 3, 'threshold_sell_steps': 8, 'step_size': 1, 'step_cnt': 3, 'operations_cnt': 1541, 'operations_avg': 6.14}

# %%
for item in sorted_results:
    print(item)
# Out:
# {'balance': 87.4, 'profit_p': '0.17', 'balance_change_avg': -0.35, 'days': 251, 'success_days': 105, 'success_p': 0.42, 'sleep_trading': 60, 'max_shares': 3, 'threshold_buy_steps': 3, 'threshold_sell_steps': 8, 'step_size': 1, 'step_cnt': 3, 'operations_cnt': 1539, 'operations_avg': 6.13}

# %%
# Вывод результатов или их дальнейшая обработка
sorted_results = sorted(sorted_results, key=lambda x: x['balance'], reverse=True)

print()
for item in sorted_results:
    print(item)

# %%
archive = sorted_results
archive
# Out:
# [{'balance': -17.9,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.17,
#   'days': 251,
#   'success_days': 163,
#   'success_p': 0.65,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 6003,
#   'operations_avg': 23.92,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -16.4,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.16,
#   'days': 251,
#   'success_days': 163,
#   'success_p': 0.65,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 6009,
#   'operations_avg': 23.94,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -16.4,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.16,
#   'days': 251,
#   'success_days': 163,
#   'success_p': 0.65,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 6009,
#   'operations_avg': 23.94,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -103.3,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.51,
#   'days': 251,
#   'success_days': 161,
#   'success_p': 0.64,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 8535,
#   'operations_avg': 34.0,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -103.9,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.51,
#   'days': 251,
#   'success_days': 161,
#   'success_p': 0.64,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 8531,
#   'operations_avg': 33.99,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -104.5,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.51,
#   'days': 251,
#   'success_days': 161,
#   'success_p': 0.64,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 8527,
#   'operations_avg': 33.97,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -68.6,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.37,
#   'days': 251,
#   'success_days': 157,
#   'success_p': 0.63,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 6605,
#   'operations_avg': 26.31,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -64.0,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.35,
#   'days': 251,
#   'success_days': 157,
#   'success_p': 0.63,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 6609,
#   'operations_avg': 26.33,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -64.0,
#   'sum': 2.499999999999943,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.35,
#   'days': 251,
#   'success_days': 157,
#   'success_p': 0.63,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 6609,
#   'operations_avg': 26.33,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 36.9,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.95,
#   'days': 251,
#   'success_days': 152,
#   'success_p': 0.61,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 4423,
#   'operations_avg': 17.62,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 39.1,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 152,
#   'success_p': 0.61,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 4423,
#   'operations_avg': 17.62,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 39.6,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 152,
#   'success_p': 0.61,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 4425,
#   'operations_avg': 17.63,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -15.3,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.16,
#   'days': 251,
#   'success_days': 147,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 4935,
#   'operations_avg': 19.66,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -15.6,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.16,
#   'days': 251,
#   'success_days': 147,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 4933,
#   'operations_avg': 19.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -15.6,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.16,
#   'days': 251,
#   'success_days': 147,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 4933,
#   'operations_avg': 19.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -184.0,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.83,
#   'days': 251,
#   'success_days': 149,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 9117,
#   'operations_avg': 36.32,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -179.9,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.81,
#   'days': 251,
#   'success_days': 149,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 9095,
#   'operations_avg': 36.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -180.8,
#   'sum': 2.7000000000001023,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.82,
#   'days': 251,
#   'success_days': 149,
#   'success_p': 0.59,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 9089,
#   'operations_avg': 36.21,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 58.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.87,
#   'days': 251,
#   'success_days': 146,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 3145,
#   'operations_avg': 12.53,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 58.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.87,
#   'days': 251,
#   'success_days': 146,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 3145,
#   'operations_avg': 12.53,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 58.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.87,
#   'days': 251,
#   'success_days': 146,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 3145,
#   'operations_avg': 12.53,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 6.5,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.07,
#   'days': 251,
#   'success_days': 145,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 4713,
#   'operations_avg': 18.78,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 9.2,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.06,
#   'days': 251,
#   'success_days': 145,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 4715,
#   'operations_avg': 18.78,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 9.7,
#   'sum': 1.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.06,
#   'days': 251,
#   'success_days': 145,
#   'success_p': 0.58,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 4717,
#   'operations_avg': 18.79,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 13.9,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -2.04,
#   'days': 251,
#   'success_days': 143,
#   'success_p': 0.57,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 3413,
#   'operations_avg': 13.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 13.9,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -2.04,
#   'days': 251,
#   'success_days': 143,
#   'success_p': 0.57,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 3413,
#   'operations_avg': 13.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 13.9,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -2.04,
#   'days': 251,
#   'success_days': 143,
#   'success_p': 0.57,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 3413,
#   'operations_avg': 13.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 40.8,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 137,
#   'success_p': 0.55,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 2579,
#   'operations_avg': 10.27,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 40.8,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 137,
#   'success_p': 0.55,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 2579,
#   'operations_avg': 10.27,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 40.8,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 137,
#   'success_p': 0.55,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 2579,
#   'operations_avg': 10.27,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -280.4,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.21,
#   'days': 251,
#   'success_days': 136,
#   'success_p': 0.54,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 11547,
#   'operations_avg': 46.0,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -280.1,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.21,
#   'days': 251,
#   'success_days': 136,
#   'success_p': 0.54,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 11549,
#   'operations_avg': 46.01,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -280.1,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.21,
#   'days': 251,
#   'success_days': 136,
#   'success_p': 0.54,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 11549,
#   'operations_avg': 46.01,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -82.5,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.43,
#   'days': 251,
#   'success_days': 133,
#   'success_p': 0.53,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 5415,
#   'operations_avg': 21.57,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -82.8,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.43,
#   'days': 251,
#   'success_days': 133,
#   'success_p': 0.53,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 5413,
#   'operations_avg': 21.57,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -82.8,
#   'sum': 2.1000000000000796,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.43,
#   'days': 251,
#   'success_days': 133,
#   'success_p': 0.53,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 5413,
#   'operations_avg': 21.57,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -130.9,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.62,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 6121,
#   'operations_avg': 24.39,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -131.5,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.62,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 6117,
#   'operations_avg': 24.37,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -131.5,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -2.62,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 6117,
#   'operations_avg': 24.37,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -27.8,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.21,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 3261,
#   'operations_avg': 12.99,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -27.8,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.21,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 3261,
#   'operations_avg': 12.99,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -27.8,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.21,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 3261,
#   'operations_avg': 12.99,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 6.6,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -2.07,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 2799,
#   'operations_avg': 11.15,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 6.6,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -2.07,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 2799,
#   'operations_avg': 11.15,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 6.6,
#   'sum': 0.5,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -2.07,
#   'days': 251,
#   'success_days': 130,
#   'success_p': 0.52,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 2799,
#   'operations_avg': 11.15,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 38.7,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.94,
#   'days': 251,
#   'success_days': 127,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 2215,
#   'operations_avg': 8.82,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 34.4,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.96,
#   'days': 251,
#   'success_days': 127,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 2217,
#   'operations_avg': 8.83,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 37.1,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.95,
#   'days': 251,
#   'success_days': 127,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 2211,
#   'operations_avg': 8.81,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 91.5,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.73,
#   'days': 251,
#   'success_days': 128,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 2063,
#   'operations_avg': 8.22,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 91.5,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.73,
#   'days': 251,
#   'success_days': 128,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 2063,
#   'operations_avg': 8.22,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 89.9,
#   'sum': 1.6000000000000227,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -1.74,
#   'days': 251,
#   'success_days': 128,
#   'success_p': 0.51,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 2059,
#   'operations_avg': 8.2,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -236.0,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -3.04,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 7063,
#   'operations_avg': 28.14,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -236.6,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -3.04,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 7059,
#   'operations_avg': 28.12,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -236.6,
#   'sum': 2.400000000000091,
#   'num': 3,
#   'sum_': 529,
#   'balance_change_avg': -3.04,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 7059,
#   'operations_avg': 28.12,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -55.7,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.32,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 3675,
#   'operations_avg': 14.64,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -55.7,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.32,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 3675,
#   'operations_avg': 14.64,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -55.7,
#   'sum': 2.0,
#   'num': 3,
#   'sum_': 528,
#   'balance_change_avg': -2.32,
#   'days': 251,
#   'success_days': 126,
#   'success_p': 0.5,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 3675,
#   'operations_avg': 14.64,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -414.9,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.75,
#   'days': 251,
#   'success_days': 124,
#   'success_p': 0.49,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 12981,
#   'operations_avg': 51.72,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -414.6,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.75,
#   'days': 251,
#   'success_days': 124,
#   'success_p': 0.49,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 12983,
#   'operations_avg': 51.73,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': -414.6,
#   'sum': 3.6000000000000796,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -3.75,
#   'days': 251,
#   'success_days': 124,
#   'success_p': 0.49,
#   'sleep_trading': 60,
#   'max_shares': 7,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 12983,
#   'operations_avg': 51.73,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 97.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.71,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 1657,
#   'operations_avg': 6.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 97.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.71,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 1657,
#   'operations_avg': 6.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 97.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.71,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 1657,
#   'operations_avg': 6.6,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 150.7,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.5,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 1311,
#   'operations_avg': 5.22,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 149.9,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.5,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 1309,
#   'operations_avg': 5.22,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 149.9,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.5,
#   'days': 251,
#   'success_days': 120,
#   'success_p': 0.48,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 1309,
#   'operations_avg': 5.22,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 83.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.77,
#   'days': 251,
#   'success_days': 119,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 1849,
#   'operations_avg': 7.37,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 83.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.77,
#   'days': 251,
#   'success_days': 119,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 1849,
#   'operations_avg': 7.37,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 83.0,
#   'sum': 3.2000000000000455,
#   'num': 3,
#   'sum_': 530,
#   'balance_change_avg': -1.77,
#   'days': 251,
#   'success_days': 119,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 1849,
#   'operations_avg': 7.37,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.2,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 118,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 1425,
#   'operations_avg': 5.68,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 122.6,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.61,
#   'days': 251,
#   'success_days': 118,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 1421,
#   'operations_avg': 5.66,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 122.6,
#   'sum': 0.8000000000000114,
#   'num': 3,
#   'sum_': 527,
#   'balance_change_avg': -1.61,
#   'days': 251,
#   'success_days': 118,
#   'success_p': 0.47,
#   'sleep_trading': 60,
#   'max_shares': 5,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 1421,
#   'operations_avg': 5.66,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 93.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.72,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 415,
#   'operations_avg': 1.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 120.1,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 167,
#   'operations_avg': 0.67,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 93.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.72,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 415,
#   'operations_avg': 1.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 93.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.72,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 415,
#   'operations_avg': 1.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 120.1,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 167,
#   'operations_avg': 0.67,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 120.1,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 167,
#   'operations_avg': 0.67,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 117.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.63,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 85,
#   'operations_avg': 0.34,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 117.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.63,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 85,
#   'operations_avg': 0.34,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 117.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.63,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 85,
#   'operations_avg': 0.34,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 100.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.7,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 299,
#   'operations_avg': 1.19,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 100.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.7,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 299,
#   'operations_avg': 1.19,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 100.7,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.7,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 299,
#   'operations_avg': 1.19,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 127.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.59,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 135,
#   'operations_avg': 0.54,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 127.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.59,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 135,
#   'operations_avg': 0.54,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 127.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.59,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 135,
#   'operations_avg': 0.54,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 143.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.53,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 143.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.53,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 143.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.53,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 5,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 79.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.78,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 449,
#   'operations_avg': 1.79,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 79.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.78,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 449,
#   'operations_avg': 1.79,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.3,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 163,
#   'operations_avg': 0.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 79.4,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.78,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 449,
#   'operations_avg': 1.79,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.3,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 163,
#   'operations_avg': 0.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.3,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 163,
#   'operations_avg': 0.65,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 109.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.66,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 73,
#   'operations_avg': 0.29,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 109.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.66,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 73,
#   'operations_avg': 0.29,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 109.0,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.66,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 5,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 73,
#   'operations_avg': 0.29,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 91.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.73,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 4,
#   'operations_cnt': 191,
#   'operations_avg': 0.76,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 91.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.73,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 5,
#   'operations_cnt': 191,
#   'operations_avg': 0.76,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 91.6,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.73,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.5,
#   'step_cnt': 7,
#   'operations_cnt': 191,
#   'operations_avg': 0.76,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 4,
#   'operations_cnt': 99,
#   'operations_avg': 0.39,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 5,
#   'operations_cnt': 99,
#   'operations_avg': 0.39,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 119.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.62,
#   'days': 251,
#   'success_days': 0,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 0.7,
#   'step_cnt': 7,
#   'operations_cnt': 99,
#   'operations_avg': 0.39,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 133.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.57,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 5,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 133.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.57,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 4,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0},
#  {'balance': 133.2,
#   'sum': 0,
#   'num': 3,
#   'sum_': 526,
#   'balance_change_avg': -1.57,
#   'days': 251,
#   'success_days': 1,
#   'success_p': 0.0,
#   'sleep_trading': 60,
#   'max_shares': 3,
#   'threshold_buy_steps': 8,
#   'threshold_sell_steps': 8,
#   'step_size': 1,
#   'step_cnt': 7,
#   'operations_cnt': 61,
#   'operations_avg': 0.24,
#   'op_not_closed': 0,
#   'op_not_closed_avg': 0.0}]

# %% [markdown]
# ## V6 Первый запуск
#
# покупка в начале, продажа в конце, фикс учитывающий изменение баланса
# 'balance': 114.7, 'success_p': 0.71,
#
# добавлена первичная покупка и продажа в конце дня
# 'balance': -347.9, 'success_p': 0.68
#
# тест разных вариантов настроек
# по проценту - 'balance': -26235.8, 'success_p': 0.73
# по сумме - 'balance': -2329.3, 'success_p': 0.23,
#
# подрезание заявок снизу
# 'balance': -16860.0, 'success_p': 0.62
#
# ```
# год -54607.4 руб  'success_p': 0.46
# {'balance': -54607.4, 'balance_change_avg': -217.56, 'days': 251, 'success_days': 115, 'success_p': 0.46, 'profit_steps': 5, 'candles_count': 4, 'sleep_trading': 300, 'take_profit_percent': 1.5, 'quit_on_balance_up_percent': 2, 'quit_on_balance_down_percent': 1, 'operations_cnt': 4859, 'operations_avg': 19.36, 'op_not_closed': 0, 'op_not_closed_avg': 0.0}
# ```
#
# ```
# день +1.8 руб
# {'balance': 1.8, 'balance_change_avg': 1.8, 'days': 1, 'success_days': 1, 'success_p': 1.0, 'profit_steps': 5, 'candles_count': 4, 'sleep_trading': 60, 'take_profit_percent': 1.5, 'quit_on_balance_up_percent': 2, 'quit_on_balance_down_percent': 1, 'operations_cnt': 12, 'operations_avg': 12.0, 'op_not_closed': 0, 'op_not_closed_avg': 0.0}
# ```
#
#
#
# ## V5 последние показатели
#
# ```
# [{'balance': -170.1,
#   'balance_change_avg': -0.68,
#   'days': 251,
#   'success_days': 71,
#   'success_p': 0.28,
#   'profit_steps': 5,
#   'candles_count': 4,
#   'sleep_trading': 60,
#   'take_profit_percent': 1.5,
#   'quit_on_balance_up_percent': 2,
#   'quit_on_balance_down_percent': 1,
#   'operations_cnt': 2758,
#   'operations_avg': 10.99,
#   'op_not_closed': 171,
#   'op_not_closed_avg': 0.68}]
# ```
#
# ## V4 результаты
#
# ```
# [{'balance': -327.3,
#   'balance_change_avg': -1.3,
#   'days': 251,
#   'success_days': 58,
#   'success_p': 0.23,
#   'profit_steps': 5,
#   'candles_count': 4,
#   'sleep_trading': 60,
#   'operations_cnt': 5020,
#   'operations_avg': 20.0,
#   'op_not_closed': 134,
#   'op_not_closed_avg': 0.53}]
# ```
#
# > {'balance': -193.7, 'balance_change_avg': -0.77, 'days': 251, 'success_days': 65, 'success_p': 0.26, 'profit_steps': 5, 'candles_count': 4, 'sleep_trading': 300, 'operations_cnt': 1390, 'operations_avg': 5.54, 'op_not_closed': 148, 'op_not_closed_avg': 0.59}
# -> -120
#
# > {'balance': -138.9, 'balance_change_avg': -0.55, 'days': 251, 'success_days': 60, 'success_p': 0.24, 'profit_steps': 5, 'candles_count': 4, 'sleep_trading': 600, 'operations_cnt': 780, 'operations_avg': 3.11, 'op_not_closed': 112, 'op_not_closed_avg': 0.45}
# -> -54
#
# > {'balance': -327.3, 'balance_change_avg': -1.3, 'days': 251, 'success_days': 58, 'success_p': 0.23, 'profit_steps': 5, 'candles_count': 4, 'sleep_trading': 60, 'operations_cnt': 5020, 'operations_avg': 20.0, 'op_not_closed': 134, 'op_not_closed_avg': 0.53}
# -> -170

# %%
fields = [
    'sum_',
    'success_p',
    'max_shares',
    'threshold_buy_steps',
    'threshold_sell_steps',
    'step_size',
    'step_cnt',
    'operations_avg',
]

# Отфильтровываем только нужные поля
filtered_data = [
    {key: item[key] for key in fields}
    for item in sorted_results
]

# %%
import pandas as pd

# Предположим, что data - это ваш список объектов
data = filtered_data

# Преобразование списка словарей в DataFrame
df = pd.DataFrame(data)

# Вычисление таблицы корреляции
correlation_matrix = df.corr()

# Вывод таблицы корреляции
# print(correlation_matrix)

# Для более наглядного отображения можно использовать seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
